# %%
import os 
import pandas as pd 
import matplotlib
matplotlib.rcParams.update({
    'font.family': 'serif'
})
import matplotlib.pyplot as plt
from pathlib import Path
import re
import numpy as np
import shutil
from plotly.offline import download_plotlyjs, init_notebook_mode,  iplot
pd.options.plotting.backend = "plotly"

# %%
def plot_kinetic_energy(input_dict_l,save_name):
    fig,ax = plt.subplots(figsize=(3,3))
    save_csv = pd.DataFrame()
    for dico in input_dict_l:
        path = dico["Path"]
        name = dico["Name"]
        csv_df = pd.read_csv(path.joinpath("KineticEnergy.csv")).drop_duplicates()
        if "timestep" not in save_csv.columns:
            save_csv["timestep"] = csv_df["timestep"]
        save_csv[name.replace('=','_')] = csv_df["KineticEnergy"]
        ax.plot(csv_df["timestep"],csv_df["KineticEnergy"],label=name)
    ax.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left')
    ax.set_xlim((0,1400))
    ax.set_ylabel("Kinetic Energy (J)")
    ax.set_xlabel("Timestep")
    plt.savefig(save_name+'.pgf',bbox_inches='tight')
    save_csv.to_csv(save_name+'.csv')

# %%
imgr0 = {
	'Path':Path('/home/juleslecoustre/Documents/Acqua/Vortices/SOLU_imgr-0/'),
	'Name':'imrgra=0'
	}
imgr1 = {
	'Path':Path('/home/juleslecoustre/Documents/Acqua/Vortices/SOLU_imgr-1/'),
	'Name':'imrgra=1'
	}
imgr2 = {
	'Path':Path('/home/juleslecoustre/Documents/Acqua/Vortices/SOLU_imgr-2/'),
	'Name':'imrgra=2'
	}
imgr3 = {
	'Path':Path('/home/juleslecoustre/Documents/Acqua/Vortices/SOLU_imgr-3/'),
	'Name':'imrgra=3'
	}
imgr4 = {
	'Path':Path('/home/juleslecoustre/Documents/Acqua/Vortices/SOLU_imgr-4/'),
	'Name':'imrgra=4'
	}
imgr5 = {
	'Path':Path('/home/juleslecoustre/Documents/Acqua/Vortices/SOLU_imgr-5/'),
	'Name':'imrgra=5'
	}
imgr6 = {
	'Path':Path('/home/juleslecoustre/Documents/Acqua/Vortices/SOLU_imgr-6/'),
	'Name':'imrgra=6'
	}
input_lst = [imgr0,imgr1,imgr2,imgr3,imgr4,imgr5,imgr6]
plot_kinetic_energy(input_lst,"GradientReconstruction")

# %%
arak0_SOLU = {
	'Path':Path('/home/juleslecoustre/Documents/Vortices/CASE1/RESU/SOLU_arak0'),
	'Name':'Solu_arak0'
	}
arak1_SOLU = {
	'Path':Path('/home/juleslecoustre/Documents/Vortices/CASE1/RESU/SOLU_arak1'),
	'Name':'Solu_arak1'
	}
arak0_Cent = {
	'Path':Path('/home/juleslecoustre/Documents/Vortices/CASE1/RESU/CenteredArak0'),
	'Name':'Centered_arak0'
	}
arak1_Cent = {
	'Path':Path('/home/juleslecoustre/Documents/Vortices/CASE1/RESU/CenteredArak1'),
	'Name':'Centered_arak1'
	}

input_lst = [arak0_SOLU,arak1_SOLU,arak0_Cent,arak1_Cent]
plot_kinetic_energy(input_lst,"RhieChow")

# %%
SOLU = {
	'Path':Path('/home/juleslecoustre/Documents/Acqua/Vortices/SOLU_withoutSlopeTest/'),
	'Name':'SOLU'
	}
UPWIND = {
	'Path':Path('/home/juleslecoustre/Documents/Acqua/Vortices/Upwind/'),
	'Name':'Upwind'
	}
Centered = {
	'Path':Path('/home/juleslecoustre/Documents/Acqua/Vortices/Centered_withoutSlopeTest/'),
	'Name':'Centered'
	}

input_lst = [UPWIND,SOLU,Centered]
plot_kinetic_energy(input_lst,"AdvScheme2nd_comparison")
